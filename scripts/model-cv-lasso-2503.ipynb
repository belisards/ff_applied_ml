# %%
from ff_custom_scripts import *
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.metrics import mean_squared_error, r2_score, brier_score_loss, f1_score
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import Lasso
from sklearn.compose import TransformedTargetRegressor
from imblearn.pipeline import Pipeline as imbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import FunctionTransformer

from imblearn.under_sampling import RandomUnderSampler

from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
train, test,leaderboard,holdout = load_files(nanvalues='remove')

alldata = pd.concat([train, test]) # all data available for training in the FF Challenge

print(train.shape, test.shape,leaderboard.shape,holdout.shape)

meta = pd.read_csv('../metadata/metadata.csv', index_col=0)

targets = ['gpa','grit','materialHardship','eviction','layoff','jobTraining']

predictors = {target: list(meta[meta[target] != 0].index) for target in targets}
# Out:
# (1172, 10396) (294, 10396) (530, 10396) (803, 10396)

# %%
# train, cv, test = load_files(nanvalues='remove')

# alldata = pd.concat([train, cv, test])

# meta = pd.read_csv('metadata.csv', index_col=0)

# targets = ['gpa','grit','materialHardship','eviction','layoff','jobTraining']

# predictors = {target: list(meta[meta[target] != 0].index) for target in targets}

# print(train.shape, cv.shape, test.shape)

# %%
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore')), 
    ('variance', VarianceThreshold(threshold=0.1)),
]
    )

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('variance', VarianceThreshold(threshold=0.1)),
    ])

ordered_transformer = Pipeline(steps=[
        # ('target', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
        ('imputer', SimpleImputer(strategy='constant', fill_value=0)),
        ('variance', VarianceThreshold(threshold=0.1)),
    ])

# %%
def run_model(X_train,Y_train,target,crossval=5,classifier=False):

    pred = predictors[target]

    X_train = X_train[pred]
    Y_train = Y_train[target]
                        
    numeric_features = cols_per_type(X_train, 'Continuous')
    categorical_features = cols_per_type(X_train, 'Unordered Categorical')
    binary_features = cols_per_type(X_train, 'Binary')
    ordered_features = cols_per_type(X_train, 'Ordered Categorical')

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, numeric_features), 
            ('cat', categorical_transformer, categorical_features),
            ('bin', ordered_transformer, binary_features),
            ('ord', ordered_transformer, ordered_features),
            ]
    )

    if classifier:
        
        logreg = LogisticRegression(penalty='l1',solver='liblinear',max_iter=10000)

        classifier = imbPipeline([('preprocessor', preprocessor),
                                     ('smote', SMOTE(random_state=42)),
                                    ('classifier', logreg),])

               
        scores = cross_validate(classifier, X_train, Y_train, cv=crossval, scoring='neg_brier_score',return_estimator=True)

        dummy = DummyClassifier(strategy='most_frequent')
        dummy.fit(X_train, Y_train)  
        Y_pred = dummy.predict(X_train)
        baseline_brier = brier_score_loss(Y_train, Y_pred)

        classifier.fit(X_train, Y_train)

        # # get dictionary of coefficients and features
        # coefs = {}
        
        # for i, feature in enumerate(X_train.columns):
        #     if classifier[-1].coef_[0][i] != 0:
        #         coefs[feature] = classifier[-1].coef_[0][i]
                
        return scores['test_score'], baseline_brier#, coefs

    else:
        
        lasso = Lasso(alpha=1000.0,max_iter=10000)

        regressor = Pipeline(steps=[('preprocessor', preprocessor),        
                                    ('regressor', lasso),])

        model = TransformedTargetRegressor(regressor=regressor, transformer=StandardScaler())

        scores = {'mse': 'neg_mean_squared_error',
                'r2': 'r2'}
        
        scores = cross_validate(model, X_train, Y_train, cv=crossval, scoring=scores,return_estimator=True)
        

        mean = np.mean(Y_train)
        Y_pred = np.full(Y_train.shape, mean)
        baseline_mse = mean_squared_error(Y_train, Y_pred)
        baseline_r2 = r2_score(Y_train, Y_pred)

        model.fit(X_train, Y_train)

        # coefs = {}

        # for i, feature in enumerate(X_train.columns):
        #     if model.regressor_[-1].coef_[i] != 0:
        #         coefs[feature] = model.regressor_[-1].coef_[i]

        # return scores['test_mse'], scores['test_r2'], baseline_mse, baseline_r2#, coefs
        return model

# run_model(X,Y,'eviction',crossval=5,classifier=True)

# %%
run_model(train,train,'eviction',crossval=5,classifier=True)

# %%
def benchmark():
    ranks = []

    for t in ['gpa','grit','materialHardship']:
        entry = {}
        print(f'Running {t}')
        mse, r2, baseline_mse, baseline_r2 = run_model(X,Y,t)
        entry['target'] = t
        entry['score'] = mse.mean() * -1
        entry['r2'] = r2.mean()
        entry['score_std'] = mse.std()
        entry['r2_std'] = r2.std()
        entry['baseline_score'] = baseline_mse
        entry['baseline_r2'] = baseline_r2
        # entry['coefs'] = coefs
        ranks.append(entry)

    for t in ['eviction','layoff','jobTraining']:
        entry = {}
        print(f'Running {t}')
        brier, baseline_brier = run_model(X,Y,t,classifier=True)
        entry['target'] = t
        entry['score'] = brier.mean() * -1
        entry['score_std'] = brier.std()
        entry['baseline_score'] = baseline_brier
        # entry['coefs'] = coefs
        ranks.append(entry)

    ranks = pd.DataFrame(ranks)

    return ranks

# %%
# removing nan values
board = benchmark()
# Out:
# Running gpa
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # removing nan values
# ----> 2 board = benchmark()
#
# Cell In[6], line 7, in benchmark()
#       5 entry = {}
#       6 print(f'Running {t}')
# ----> 7 mse, r2, baseline_mse, baseline_r2 = run_model(X,Y,t)
#       8 entry['target'] = t
#       9 entry['score'] = mse.mean() * -1
#
# NameError: name 'X' is not defined

# %%
board
# Out:
#              target     score        r2  score_std    r2_std  baseline_score  \
# 0               gpa  0.394977  0.077777   0.033676  0.021614        0.428469
# 1              grit  0.224600 -0.004820   0.025785  0.011696        0.224958
# 2  materialHardship  0.021594  0.063545   0.002133  0.030413        0.023115
# 3          eviction  0.135518       NaN   0.019218       NaN        0.060158
# 4            layoff  0.313445       NaN   0.027306       NaN        0.198225
# 5       jobTraining  0.357322       NaN   0.016957       NaN        0.263314
#
#    baseline_r2
# 0          0.0
# 1          0.0
# 2          0.0
# 3          NaN
# 4          NaN
# 5          NaN

# %%
board.to_csv('benchmark_lasso.csv')

# %% [markdown]
# # Explore coefficients

# %%
def getfeat_name(feat):
    name = meta[meta.index == feat].varlab.values[0]
    return name

def get_top_features(df, n=10):
    top_features = []
    for col in df.columns:
        entry = {}
        idvars = df[col].sort_values(ascending=False)[:n].index.tolist()
        vars = [getfeat_name(var) for var in idvars]
        entry['target'] = col
        entry['id'] = idvars
        entry['feature'] = vars
        top_features.append(entry)
    
    return pd.DataFrame(top_features)

# %%
coefs = pd.DataFrame(board['coefs'].apply(pd.Series)).set_index(board.target).T

# %%
# show pandas in full column widt
pd.set_option('display.max_colwidth', None)
get_top_features(coefs).explode(['feature','id'])
# Out:
#              target             id  \
# 0               gpa          m2a8d
# 0               gpa           f2b6
# 0               gpa        m1b10a7
# 0               gpa           f2l6
# 0               gpa          f1b16
# 0               gpa           f1h2
# 0               gpa         f1b9a2
# 0               gpa          m1b6a
# 0               gpa          m1d2g
# 0               gpa         f1b9a5
# 1              grit          f2l5a
# 1              grit          m1d3d
# 1              grit         f1b9a5
# 1              grit          f2c21
# 1              grit         f2g11b
# 1              grit         f1b15e
# 1              grit         f1b9a2
# 1              grit          f1b16
# 1              grit           f1h2
# 1              grit          m1b6a
# 2  materialHardship          f2d5h
# 2  materialHardship          m2a4b
# 2  materialHardship         f1e1d7
# 2  materialHardship         f2f2d4
# 2  materialHardship          m2c6a
# 2  materialHardship         f2j20c
# 2  materialHardship         f1b9a2
# 2  materialHardship          f1b16
# 2  materialHardship           f1h2
# 2  materialHardship          m1b6a
# 3          eviction          f1b5d
# 3          eviction           f1a6
# 3          eviction           m1i3
# 3          eviction         m1b9b5
# 3          eviction       f2c15fb1
# 3          eviction        m2b31cp
# 3          eviction        cm2marf
# 3          eviction           f2b8
# 3          eviction           f2k7
# 3          eviction          m1b4b
# 4            layoff        f1b10a5
# 4            layoff        cm2amrf
# 4            layoff         f2k7b6
# 4            layoff          f2h5a
# 4            layoff         f2k5a5
# 4            layoff          m2a4b
# 4            layoff          f1d3a
# 4            layoff          f1c5b
# 4            layoff  q2citywt_rep8
# 4            layoff          f1f15
# 5       jobTraining          m1b4f
# 5       jobTraining          t5b2c
# 5       jobTraining           m1f9
# 5       jobTraining         t5e17a
# 5       jobTraining         p5h1cd
# 5       jobTraining        f2a7c1b
# 5       jobTraining          m1i4b
# 5       jobTraining         m2b43b
# 5       jobTraining          m5i23
# 5       jobTraining  m1citywt_rep6
#
#                                                                             feature
# 0                   Int Chk: Are mother and father currently romantically involved?
# 0     # of times since birth child been to health care professional for well-visit?
# 0                                   Reason no plan to marry, Relationship reasons ?
# 0                                         Do you or wife/partner own car/truck/van?
# 0       During bio mom preg, did you give her money or buy things for the baby/ies?
# 0                                                              Were you born in US?
# 0                                 Reasons no plan to live together, Timing problem?
# 0             When you and bio dad together how often did you disagree about money?
# 0                         How imp for successful marriage, both emotionally mature?
# 0                                  Reasons no plan to live together, Incarceration?
# 1                                      Is the credit card in hers/yours/both names?
# 1             In dating, a man is largely out to take advantage of a woman, Ag/Dis?
# 1                                  Reasons no plan to live together, Incarceration?
# 1                               Do you pay support for any of those other children?
# 1                                     Int Chk: Did respondent have a father-figure?
# 1                                  How life diff if married bio mom, your sex life?
# 1                                 Reasons no plan to live together, Timing problem?
# 1       During bio mom preg, did you give her money or buy things for the baby/ies?
# 1                                                              Were you born in US?
# 1             When you and bio dad together how often did you disagree about money?
# 2                    How often does mother-listen when you need someone to talk to?
# 2                               About how long has child been living there (month)?
# 2                                   People who currently live in your HH - 7th age?
# 2                                      What is fourth person's relationship to you?
# 2  How often(1=Very 4=Never)does father-Watch child when mother needs to do things?
# 2                            When you were/are worried, were you also-easily tired?
# 2                                 Reasons no plan to live together, Timing problem?
# 2       During bio mom preg, did you give her money or buy things for the baby/ies?
# 2                                                              Were you born in US?
# 2             When you and bio dad together how often did you disagree about money?
# 3                   Last mo did you and bio mom, helped each other solve a problem?
# 3                                            Do you have other biological children?
# 3            What is the highest grade/years of school that bio dad have completed?
# 3                                   Reasons aren't living together, Incarceration ?
# 3                                                 Range of amount given?-($ Amount)
# 3                                                             Per what time period?
# 3                    Constructed - Is mother married to child's father at one-year?
# 3                      How many times since birth has child been to emergency room?
# 3                                 Int Chk: Is the respondent at least 22 years old?
# 3           Why did rom rel end with (bio dad), Distance (Don't live in same town)?
# 4                                          Reasons no plan to marry, Incarceration?
# 4                     Constructed - How old was the mother when she married father?
# 4                        What program/schooling did you attend?-Reading improvement
# 4            Int Chk: Does respondent live with family or friends, but pay no rent?
# 4                   What program/schooling have you completed?-Business/Secretarial
# 4                               About how long has child been living there (month)?
# 4                The imp decisions in the family should be done by the man, Ag/Dis?
# 4       If bio dad can afford financial supp but doesn't - right to make decisions?
# 4                                       Couple one-year city replicate weight no. 8
# 4    If bio dad doesn't want to marry likely, he'll be required to pay child supp.?
# 5                             Why did rom rel end with (bio dad), Violence, Abuse ?
# 5                                                    B2C. Child works independently
# 5          Can mother receive welfare if she is not married and lives with bio dad?
# 5          E17A. Frequency you do spelling/punctuation/grammar exercises with class
# 5                           H1CD. Frequency child used rescue inhaler in past month
# 5                                          When did you and mother separate? (Year)
# 5                        Is bio dad Mexican, Puerto Rican, Cuban or other Hispanic?
# 5      On a scale of 1-(least like) to 5-(most like) - Child often fusses and cries
# 5   I23. Range of regular jobs lasting 2 wks or more you have had in past 12 months
# 5                                       Mother baseline city replicate weight no. 6
