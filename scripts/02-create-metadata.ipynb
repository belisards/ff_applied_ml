# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import json
from sklearn.feature_selection import VarianceThreshold

# %%
meta = pd.read_csv('../data/FFMetadata_v10.csv',low_memory=False)
df = pd.read_csv('../data/FFChallenge_v5/background.csv',low_memory=False,index_col=0)
constant = pd.read_csv('../data/FFChallenge_v5/constantVariables.txt',header=None,index_col=0)

print(f'Background: {df.shape[1]} variables')

print(f'Meta: {meta.shape[0]} variables')

print(f'Constant: {constant.shape[0]} variables')
# Out:
# Background: 13026 variables
# Meta: 25684 variables
# Constant: 2432 variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4242 entries, 1 to 4242
# Columns: 13026 entries, cf1intmon to k5f1
# dtypes: float64(544), int64(12366), object(116)
# memory usage: 421.6+ MB

# %%
# df = df[df.columns[df.columns.isin(meta.new_name)]]

df.columns[df.columns.isin(meta.new_name)]
# Out:
# Index(['cf1intmon', 'cf1intyr', 'cf1lenhr', 'cf1lenmin', 'cf1twoc', 'cf1fint',
#        'cf1natsm', 'f1natwt', 'cf1natsmx', 'f1natwtx',
#        ...
#        'q5citywt_rep63', 'q5citywt_rep64', 'q5citywt_rep65', 'q5citywt_rep66',
#        'q5citywt_rep67', 'q5citywt_rep68', 'q5citywt_rep69', 'q5citywt_rep70',
#        'q5citywt_rep71', 'q5citywt_rep72'],
#       dtype='object', length=12840)

# %% [markdown]
# # Drop constantVariables.txt

# %%
fixed = df.drop(constant.index.values,axis=1)

print(f'Background without constant: {fixed.shape[1]} variables')
# Out:
# Background without constant: 10594 variables

# %% [markdown]
# # Drop columns with excessive real missing values

# %%
def dropvars(df,nan_threshold=0.8):
    # thresh = Require that many non-NA values 
    return df.dropna(thresh=len(df)*nan_threshold, axis=1)

filled = dropvars(fixed)

filled
# Out:
#              cf1lenhr  cf1lenmin  cf1fint  cf1citsm   f1citywt  f1a2  f1a3  \
# challengeID
# 1                  -9         -9        0        -9  -3.000000    -9    -9
# 2                   0         40        1         1  68.455658     2     1
# 3                   0         45        1         1  42.319057     1     1
# 4                   0         45        1         1  25.628830     1     1
# 5                  -6         50        1         1  41.954487     2     1
# ...               ...        ...      ...       ...        ...   ...   ...
# 4238               -9         -9        0        -9  -3.000000    -9    -9
# 4239                0         40        1         1  64.195152     2     1
# 4240               -9         -9        0        -9  -3.000000    -9    -9
# 4241                1          0        1         1  27.461493     2     1
# 4242               -9         -9        0        -9  -3.000000    -9    -9
#
#              f1a4  f1a4a  f1a5  ...       m4d9      m4e23       f4d6  \
# challengeID                     ...
# 1              -9     -9    -9  ...   6.269946   5.180325   2.511131
# 2               1     -6     1  ...   6.269946  27.680196   2.511131
# 3               1     -6     1  ...   6.269946   5.180325  20.867881
# 4               1     -6     1  ...   6.269946   5.180325  22.018875
# 5               1     -6     1  ...   6.269946   5.180325  22.916602
# ...           ...    ...   ...  ...        ...        ...        ...
# 4238           -9     -9    -9  ...  27.941956   5.180325   2.511131
# 4239            1     -6     1  ...  28.703663   5.180325   2.511131
# 4240           -9     -9    -9  ...   6.269946  26.990283   2.511131
# 4241            2      1     1  ...   6.269946  27.189692   2.511131
# 4242           -9     -9    -9  ...   6.269946   5.180325  23.558317
#
#                   f4d7       f4d9       m5c6      m5d20     m5k10       f5c6  \
# challengeID
# 1             1.718804   6.473537  16.369411   4.476881  9.628369  15.981275
# 2             1.718804   6.473537  16.369411  26.671897  9.628369  15.981275
# 3            24.115867   6.473537  16.369411   4.476881  9.628369  15.981275
# 4            22.932641   6.473537  -5.169243   4.476881  9.628369  -6.303171
# 5            22.988036   6.473537  -6.034660   4.476881  9.628369  -6.211828
# ...                ...        ...        ...        ...       ...        ...
# 4238          1.718804   6.473537  16.369411   4.476881  9.628369  15.981275
# 4239          1.718804   6.473537  16.369411   4.476881  9.628369  15.981275
# 4240          1.718804   6.473537  16.369411   4.476881  9.628369  15.981275
# 4241          1.718804  28.512659  16.369411   4.476881  9.628369  -6.009855
# 4242         23.937457   6.473537  -5.424175   4.476881  9.628369  -5.812319
#
#                   k5f1
# challengeID
# 1            24.038266
# 2             3.667679
# 3            24.038266
# 4             4.140511
# 5             3.668879
# ...                ...
# 4238         24.038266
# 4239          3.424922
# 4240         24.038266
# 4241          3.656543
# 4242          3.424922
#
# [4242 rows x 10479 columns]

# %%
print(f'Background without excessive missing/low-variance values: {filled.shape[1]} variables')
# Out:
# Background without excessive missing/low-variance values: 10479 variables

# %% [markdown]
# # Select only variables with metadata

# %%
cols = [col for col in filled.columns if col in meta.new_name.values]

filled[cols]
# Out:
#              cf1lenhr  cf1lenmin  cf1fint  cf1citsm   f1citywt  f1a2  f1a3  \
# challengeID
# 1                  -9         -9        0        -9  -3.000000    -9    -9
# 2                   0         40        1         1  68.455658     2     1
# 3                   0         45        1         1  42.319057     1     1
# 4                   0         45        1         1  25.628830     1     1
# 5                  -6         50        1         1  41.954487     2     1
# ...               ...        ...      ...       ...        ...   ...   ...
# 4238               -9         -9        0        -9  -3.000000    -9    -9
# 4239                0         40        1         1  64.195152     2     1
# 4240               -9         -9        0        -9  -3.000000    -9    -9
# 4241                1          0        1         1  27.461493     2     1
# 4242               -9         -9        0        -9  -3.000000    -9    -9
#
#              f1a4  f1a4a  f1a5  ...     cf5hhincb  cf5hhimpb  cm5povco  \
# challengeID                     ...
# 1              -9     -9    -9  ...     -9.000000         -9 -9.000000
# 2               1     -6     1  ...     -9.000000         -9  0.842485
# 3               1     -6     1  ...     -9.000000         -9 -9.000000
# 4               1     -6     1  ...  55377.768078          1  2.755591
# 5               1     -6     1  ...   8347.302339          1  0.744948
# ...           ...    ...   ...  ...           ...        ...       ...
# 4238           -9     -9    -9  ...     -9.000000         -9 -9.000000
# 4239            1     -6     1  ...   3668.270229          5  0.977176
# 4240           -9     -9    -9  ...     -9.000000         -9 -9.000000
# 4241            2      1     1  ...   9344.401596          5  0.785042
# 4242           -9     -9    -9  ...  39341.701332          1  0.963017
#
#              cf5povco  cf5povcob  cm5povca  cf5povca  cf5povcab  cm5samp  \
# challengeID
# 1           -9.000000  -9.000000        -9        -9         -9        6
# 2           -9.000000  -9.000000         1        -9         -9       -7
# 3           -9.000000  -9.000000        -9        -9         -9        7
# 4            1.807249   2.722656         4         3          4       -7
# 5            0.951748   0.970510         1         2          1       -7
# ...               ...        ...       ...       ...        ...      ...
# 4238        -9.000000  -9.000000        -9        -9         -9        3
# 4239         0.424686   0.965887         2         2          2       -7
# 4240        -9.000000  -9.000000        -9        -9         -9        5
# 4241         0.373246   0.000000         2         1          1       -7
# 4242         0.207946   0.000000         3         3          3       -7
#
#              cf5samp
# challengeID
# 1                  6
# 2                  1
# 3                  7
# 4                 -7
# 5                 -7
# ...              ...
# 4238               3
# 4239              -7
# 4240               6
# 4241              -7
# 4242              -7
#
# [4242 rows x 10391 columns]

# %% [markdown]
# # Remove variables malformed

# %%
# dtypes[dtypes.new_name == 'cf4fint']
# string = '1960-01-02'
# mask = df.isin(['1960-01-01']).any()
# df.columns[mask]

malformed = {
    'r3b26_a': 'Has text instead of numerical encodings',
    'cf4fint': 'cf4fint encoded as binary but has 1960-01-01',
}

# remove malformed keys from cols if they exist
for key in malformed.keys():
    if key in cols:
        cols.remove(key)
        print(f'Removed {key} from cols')
# Out:
# Removed cf4fint from cols

# %% [markdown]
# # Explore variables
# ## By type of variable

# %%
meta.source.value_counts()
# Out:
# questionnaire    12619
# restricted        8350
# constructed       2206
# weight            2176
# saliva             263
# actigraphy          69
# idnum                1
# Name: source, dtype: int64

# %%
meta[meta.new_name.isin(cols)].source.value_counts()
# Out:
# questionnaire    9746
# constructed       523
# weight            121
# Name: source, dtype: int64

# %% [markdown]
# ## By datatypes and topics

# %%
meta[meta.new_name.isin(cols)].type.value_counts()
# Out:
# Binary                   4800
# Ordered Categorical      2987
# Continuous               1628
# Unordered Categorical     975
# Name: type, dtype: int64

# %%
meta[meta.new_name.isin(cols)].topics.value_counts().head(15)
# Out:
# Finances                                   1633
# Health and health behavior                 1071
# Housing and neighborhood                    858
# Parenting                                   833
# Cognitive and behavioral development        730
# Romantic relationships                      674
# Education and school                        591
# Childcare                                   504
# Employment                                  307
# Paradata and weights                        251
# Housing and neighborhood ; Demographics     238
# Legal system                                206
# Family and social ties                      201
# Demographics                                129
# Attitudes and expectations                  108
# Name: topics, dtype: int64

# %% [markdown]
# # Export metadata

# %%
myvars = meta[meta.new_name.isin(cols)].copy()

myvars['one_topic'] = myvars['topics'].str.split(';').str[0]

# trim one topic
myvars['one_topic'] = myvars['one_topic'].str.strip()

# remove space and upper case
myvars['one_topic'] = myvars['one_topic'].str.replace(' ','_').str.lower()

dtypes = myvars[['new_name','varlab','type','one_topic']].copy()

dtypes
# Out:
#         new_name                                             varlab  \
# 3       cf1lenhr     What was the total length of interview - Hours
# 4      cf1lenmin   What was the total length of interview - Minutes
# 6        cf1fint  Constructed - Was father interviewed at baseline?
# 11      cf1citsm            Constructed - Baseline city sample flag
# 12      f1citywt  Father baseline city sample weight (20-cities ...
# ...          ...                                                ...
# 12790   cm5povca  Constructed - Mother's poverty category at 9-year
# 12791   cf5povca  Constructed - Father's poverty category at 9-year
# 12792  cf5povcab  Constructed - Father's poverty category at 9-y...
# 12793    cm5samp    Constructed - Y9 reason for mother non-response
# 12794    cf5samp    Constructed - Y9 reason for father non-response
#
#                         type             one_topic
# 3                 Continuous  paradata_and_weights
# 4                 Continuous  paradata_and_weights
# 6                     Binary  paradata_and_weights
# 11                    Binary  paradata_and_weights
# 12                Continuous  paradata_and_weights
# ...                      ...                   ...
# 12790    Ordered Categorical              finances
# 12791    Ordered Categorical              finances
# 12792    Ordered Categorical              finances
# 12793  Unordered Categorical  paradata_and_weights
# 12794  Unordered Categorical  paradata_and_weights
#
# [10390 rows x 4 columns]

# %%
ordcat_list = dtypes[dtypes.type == 'Ordered Categorical']

dictdtype = {
    'Binary': 'object', # binary encoded with 1/2 instead of 0/1 so we will convert it later
    'Ordered Categorical': CategoricalDtype(categories=ordcat_list, ordered=True),
    # 'Ordered Categorical to integer': 'int8',
    # 'Ordered Categorical': 'object', 
    'Continuous': 'float64',
    'Unordered Categorical': 'category',
}

dtypes['dtype'] = dtypes.type.map(dictdtype)

miscores = pd.read_csv('../metadata/miscores.csv',index_col=0)

dtypes = dtypes.set_index('new_name').join(miscores).reset_index()

dtypes
# Out:
#         new_name                                             varlab  \
# 0       cf1lenhr     What was the total length of interview - Hours
# 1      cf1lenmin   What was the total length of interview - Minutes
# 2        cf1fint  Constructed - Was father interviewed at baseline?
# 3       cf1citsm            Constructed - Baseline city sample flag
# 4       f1citywt  Father baseline city sample weight (20-cities ...
# ...          ...                                                ...
# 10385   cm5povca  Constructed - Mother's poverty category at 9-year
# 10386   cf5povca  Constructed - Father's poverty category at 9-year
# 10387  cf5povcab  Constructed - Father's poverty category at 9-y...
# 10388    cm5samp    Constructed - Y9 reason for mother non-response
# 10389    cf5samp    Constructed - Y9 reason for father non-response
#
#                         type             one_topic     dtype       gpa  \
# 0                 Continuous  paradata_and_weights   float64  0.000000
# 1                 Continuous  paradata_and_weights   float64  0.000000
# 2                     Binary  paradata_and_weights    object  0.021894
# 3                     Binary  paradata_and_weights    object  0.012485
# 4                 Continuous  paradata_and_weights   float64  0.000000
# ...                      ...                   ...       ...       ...
# 10385    Ordered Categorical              finances  category  0.000000
# 10386    Ordered Categorical              finances  category  0.000000
# 10387    Ordered Categorical              finances  category  0.000000
# 10388  Unordered Categorical  paradata_and_weights  category  0.000000
# 10389  Unordered Categorical  paradata_and_weights  category  0.005367
#
#            grit  materialHardship  eviction    layoff  jobTraining
# 0      0.009892          0.003785  0.000000  0.007810     0.000000
# 1      0.000000          0.000000  0.001409  0.000000     0.000000
# 2      0.018859          0.016743  0.028699  0.000000     0.000000
# 3      0.023336          0.011364  0.000000  0.016590     0.004293
# 4      0.000000          0.000000  0.009234  0.002574     0.014284
# ...         ...               ...       ...       ...          ...
# 10385  0.000000          0.033440  0.031431  0.000000     0.015174
# 10386  0.030205          0.000000  0.000000  0.000000     0.001519
# 10387  0.000000          0.000000  0.016226  0.000454     0.000983
# 10388  0.015793          0.013264  0.000000  0.000000     0.000000
# 10389  0.000000          0.008293  0.000000  0.000000     0.000000
#
# [10390 rows x 11 columns]

# %% [markdown]
# # Export metadata.json

# %%
dtypes_dict = dict(zip(dtypes.new_name,dtypes.dtype))
dtypes_dict = {'challengeID': 'int64', **dtypes_dict}

dtypes_dict = {k: str(v) if isinstance(v, CategoricalDtype) else v for k, v in dtypes_dict.items()}

with open('../metadata/metadata.json', 'w') as fp:
    json.dump(dtypes_dict, fp)

# %%
pd.read_csv('../data/FFChallenge_v5/background.csv',low_memory=False, \
                            dtype=dtypes_dict,\
                            usecols=dtypes_dict.keys()).set_index('challengeID')
# Out:
#              cf1lenhr  cf1lenmin cf1fint cf1citsm   f1citywt f1a2 f1a3 f1a4  \
# challengeID
# 1                -9.0       -9.0       0       -9  -3.000000   -9   -9   -9
# 2                 0.0       40.0       1        1  68.455658    2    1    1
# 3                 0.0       45.0       1        1  42.319057    1    1    1
# 4                 0.0       45.0       1        1  25.628830    1    1    1
# 5                -6.0       50.0       1        1  41.954487    2    1    1
# ...               ...        ...     ...      ...        ...  ...  ...  ...
# 4238             -9.0       -9.0       0       -9  -3.000000   -9   -9   -9
# 4239              0.0       40.0       1        1  64.195152    2    1    1
# 4240             -9.0       -9.0       0       -9  -3.000000   -9   -9   -9
# 4241              1.0        0.0       1        1  27.461493    2    1    2
# 4242             -9.0       -9.0       0       -9  -3.000000   -9   -9   -9
#
#             f1a4a f1a5  ...     cf5hhincb cf5hhimpb  cm5povco  cf5povco  \
# challengeID             ...
# 1              -9   -9  ...     -9.000000        -9 -9.000000 -9.000000
# 2              -6    1  ...     -9.000000        -9  0.842485 -9.000000
# 3              -6    1  ...     -9.000000        -9 -9.000000 -9.000000
# 4              -6    1  ...  55377.768078         1  2.755591  1.807249
# 5              -6    1  ...   8347.302339         1  0.744948  0.951748
# ...           ...  ...  ...           ...       ...       ...       ...
# 4238           -9   -9  ...     -9.000000        -9 -9.000000 -9.000000
# 4239           -6    1  ...   3668.270229         5  0.977176  0.424686
# 4240           -9   -9  ...     -9.000000        -9 -9.000000 -9.000000
# 4241            1    1  ...   9344.401596         5  0.785042  0.373246
# 4242           -9   -9  ...  39341.701332         1  0.963017  0.207946
#
#              cf5povcob  cm5povca cf5povca cf5povcab cm5samp cf5samp
# challengeID
# 1            -9.000000        -9       -9        -9       6       6
# 2            -9.000000         1       -9        -9      -7       1
# 3            -9.000000        -9       -9        -9       7       7
# 4             2.722656         4        3         4      -7      -7
# 5             0.970510         1        2         1      -7      -7
# ...                ...       ...      ...       ...     ...     ...
# 4238         -9.000000        -9       -9        -9       3       3
# 4239          0.965887         2        2         2      -7      -7
# 4240         -9.000000        -9       -9        -9       5       6
# 4241          0.000000         2        1         1      -7      -7
# 4242          0.000000         3        3         3      -7      -7
#
# [4242 rows x 10390 columns]

# %%
dtypes.to_csv('../metadata/metadata.csv',index=False)
